# %% [markdown]
# ## Web Scraping
# Web Scraping is the extraction of data from a website, and in this case, the Python library called **Beautiful Soup** will be used. The scraper loads the HTML code of the page the user wants to collect data from, then the scraper will either extract all the data on the page or the user will go through the process of selecting the specific data they want from the page. That is done by looking at the website’s HTML code and selecting the the specific element or tag that the desired information is in.
#
# ### Data to Scrape
# In this practical we will look at how to do web scraping on imdb.com to fetch information about movies with different genres using Python BeautifulSoup and requests. IMDB (Internet Movie Database) website is owned by Amazon, is one of the best platforms for finding information about films, television shows, web series, etc.
#
# The data that we want to extract from it are:
# * Movie title
# * Release date
# * Genre
# * Movie length
# * Movie certification
# * Rating
# * Metascore
# * Description
# * Votes
#
# To extract all of this data, our scrapper will need to go inside each film’s webpage. Now let's start scrapping.

# %% [markdown]
# ## Load Libraries
# Before we begin, we need to import the libraries that will be used for this practical.

# %%
# Load packages
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## Getting URLs of different pages
# The first thing we need to do is to get URLs of different movie genres, for example, the genres include Adventure, Animation, Drama, Comedy, Horror, etc.

# %%
genres = ["Adventure","Animation", "Biography", "Comedy", "crime", "Drama", "Family", "Fantasy", "Film-Noir", "History", "Horror", "Thriller", "Music", "Musical", "Mystery", "Romance","Sci-Fi", "Sport","War","Western"]

url_dict = {}

for genre in genres:
    url = "https://www.imdb.com/search/title/?genres={}"
    formated_url = url.format(genre)
    url_dict[genre] = formated_url


print(url_dict)
# Out:
# {'Adventure': 'https://www.imdb.com/search/title/?genres=Adventure', 'Animation': 'https://www.imdb.com/search/title/?genres=Animation', 'Biography': 'https://www.imdb.com/search/title/?genres=Biography', 'Comedy': 'https://www.imdb.com/search/title/?genres=Comedy', 'crime': 'https://www.imdb.com/search/title/?genres=crime', 'Drama': 'https://www.imdb.com/search/title/?genres=Drama', 'Family': 'https://www.imdb.com/search/title/?genres=Family', 'Fantasy': 'https://www.imdb.com/search/title/?genres=Fantasy', 'Film-Noir': 'https://www.imdb.com/search/title/?genres=Film-Noir', 'History': 'https://www.imdb.com/search/title/?genres=History', 'Horror': 'https://www.imdb.com/search/title/?genres=Horror', 'Thriller': 'https://www.imdb.com/search/title/?genres=Thriller', 'Music': 'https://www.imdb.com/search/title/?genres=Music', 'Musical': 'https://www.imdb.com/search/title/?genres=Musical', 'Mystery': 'https://www.imdb.com/search/title/?genres=Mystery', 'Romance': 'https://www.imdb.com/search/title/?genres=Romance', 'Sci-Fi': 'https://www.imdb.com/search/title/?genres=Sci-Fi', 'Sport': 'https://www.imdb.com/search/title/?genres=Sport', 'War': 'https://www.imdb.com/search/title/?genres=War', 'Western': 'https://www.imdb.com/search/title/?genres=Western'}

# %% [markdown]
# ## Parsing Movie Information
# Now let's parse the movie information from IMDB. We will work with one genre first.

# %%
url = 'https://www.imdb.com/search/title/?genres=Adventure'
# Sending a request to the speciifed URL
resp = requests.get(url)
# Converting the response to Beautiful Soup Object
content = BeautifulSoup(resp.content, 'lxml')

# %%
# Iterating throught the List of movies
for movie in content.select('.lister-item-content'):
    try:
    # Creating a python dictonary
        data = {
            "title": movie.select('.lister-item-header')[0].get_text().strip(),
            "year": movie.select('.lister-item-year')[0].get_text().strip(),
            "certificate": movie.select('.certificate')[0].get_text().strip(),
            "time": movie.select(".runtime")[0].get_text().strip(),
            "genre": movie.select(".genre")[0].get_text().strip(),
            "rating": movie.select(".ratings-imdb-rating")[0].get_text().strip(),
            "metascore": movie.select(".metascore")[0].get_text().strip(),
            "simple_desc": movie.select(".text-muted")[2].get_text().strip(),
            "votes": movie.select(".sort-num_votes-visible")[0].get_text().strip(),
        }
    except IndexError:
        continue


    print(data)
# Out:
# {'title': '1.\nGuardians of the Galaxy Vol. 3\n(2023)', 'year': '(2023)', 'certificate': 'PG13', 'time': '150 min', 'genre': 'Action, Adventure, Comedy', 'rating': '8.3', 'metascore': '64', 'simple_desc': 'Still reeling from the loss of Gamora, Peter Quill rallies his team to defend the universe and one of their own - a mission that could mean the end of the Guardians if not successful.', 'votes': 'Votes:\n123,203'}
# {'title': '2.\nDungeons & Dragons: Honor Among Thieves\n(2023)', 'year': '(2023)', 'certificate': 'PG13', 'time': '134 min', 'genre': 'Action, Adventure, Comedy', 'rating': '7.4', 'metascore': '72', 'simple_desc': 'A charming thief and a band of unlikely adventurers embark on an epic quest to retrieve a lost relic, but things go dangerously awry when they run afoul of the wrong people.', 'votes': 'Votes:\n99,139'}
# {'title': '3.\nThe Super Mario Bros. Movie\n(2023)', 'year': '(2023)', 'certificate': 'PG', 'time': '92 min', 'genre': 'Animation, Adventure, Comedy', 'rating': '7.2', 'metascore': '46', 'simple_desc': 'The story of The Super Mario Bros. on their journey through the Mushroom Kingdom.', 'votes': 'Votes:\n111,060'}
# {'title': '10.\nGuardians of the Galaxy\n(2014)', 'year': '(2014)', 'certificate': 'PG13', 'time': '121 min', 'genre': 'Action, Adventure, Comedy', 'rating': '8.0', 'metascore': '76', 'simple_desc': 'A group of intergalactic criminals must pull together to stop a fanatical warrior with plans to purge the universe.', 'votes': 'Votes:\n1,212,863\n| Gross:\n$333.18M'}
# {'title': '11.\nPeter Pan & Wendy\n(2023)', 'year': '(2023)', 'certificate': 'PG', 'time': '106 min', 'genre': 'Action, Adventure, Comedy', 'rating': '4.1', 'metascore': '61', 'simple_desc': 'Follow the adventures of Peter Pan, a boy who does not want to grow up, and how he recruits three siblings in London, and together they embark on a magical adventure on the enchanted island of Neverland.', 'votes': 'Votes:\n20,047'}
# {'title': '12.\nGhosted\n(I) (2023)', 'year': '(I) (2023)', 'certificate': 'NC16', 'time': '116 min', 'genre': 'Action, Adventure, Comedy', 'rating': '5.8', 'metascore': '34', 'simple_desc': "Cole falls head over heels for enigmatic Sadie, but then makes the shocking discovery that she's a secret agent. Before they can decide on a second date, Cole and Sadie are swept away on an international adventure to save the world.", 'votes': 'Votes:\n37,357'}
# {'title': '14.\nGuardians of the Galaxy Vol. 2\n(2017)', 'year': '(2017)', 'certificate': 'PG13', 'time': '136 min', 'genre': 'Action, Adventure, Comedy', 'rating': '7.6', 'metascore': '67', 'simple_desc': "The Guardians struggle to keep together as a team while dealing with their personal family issues, notably Star-Lord's encounter with his father, the ambitious celestial being Ego.", 'votes': 'Votes:\n710,520\n| Gross:\n$389.81M'}
# {'title': '15.\nFast X\n(2023)', 'year': '(2023)', 'certificate': 'PG13', 'time': '141 min', 'genre': 'Action, Adventure, Crime', 'rating': '6.4', 'metascore': '55', 'simple_desc': 'Dom Toretto and his family are targeted by the vengeful son of drug kingpin Hernan Reyes.', 'votes': 'Votes:\n12,746'}
# {'title': '19.\nAnt-Man and the Wasp: Quantumania\n(2023)', 'year': '(2023)', 'certificate': 'PG', 'time': '124 min', 'genre': 'Action, Adventure, Comedy', 'rating': '6.2', 'metascore': '48', 'simple_desc': "Scott Lang and Hope Van Dyne are dragged into the Quantum Realm, along with Hope's parents and Scott's daughter Cassie. Together they must find a way to escape, but what secrets is Hope's mother hiding? And who is the mysterious Kang?", 'votes': 'Votes:\n145,150'}
# {'title': '21.\nDune: Part One\n(2021)', 'year': '(2021)', 'certificate': 'PG13', 'time': '155 min', 'genre': 'Action, Adventure, Drama', 'rating': '8.0', 'metascore': '74', 'simple_desc': "A noble family becomes embroiled in a war for control over the galaxy's most valuable asset while its heir becomes troubled by visions of a dark future.", 'votes': 'Votes:\n674,432\n| Gross:\n$108.33M'}
# {'title': '22.\nAvatar: The Way of Water\n(2022)', 'year': '(2022)', 'certificate': 'PG13', 'time': '192 min', 'genre': 'Action, Adventure, Fantasy', 'rating': '7.7', 'metascore': '67', 'simple_desc': "Jake Sully lives with his newfound family formed on the extrasolar moon Pandora. Once a familiar threat returns to finish what was previously started, Jake must work with Neytiri and the army of the Na'vi race to protect their home.", 'votes': 'Votes:\n380,345\n| Gross:\n$659.68M'}
# {'title': '29.\nKnights of the Zodiac\n(2023)', 'year': '(2023)', 'certificate': 'PG13', 'time': '112 min', 'genre': 'Action, Adventure, Drama', 'rating': '4.6', 'metascore': '34', 'simple_desc': 'When a goddess of war reincarnates in the body of a young girl, street orphan Seiya discovers that he is destined to protect her and save the world. But only if he can face his own past and become a Knight of the Zodiac.', 'votes': 'Votes:\n2,568'}
# {'title': '31.\nEverything Everywhere All at Once\n(2022)', 'year': '(2022)', 'certificate': 'M18', 'time': '139 min', 'genre': 'Action, Adventure, Comedy', 'rating': '7.8', 'metascore': '81', 'simple_desc': 'A middle-aged Chinese immigrant is swept up into an insane adventure in which she alone can save existence by exploring other universes and connecting with the lives she could have led.', 'votes': 'Votes:\n444,734\n| Gross:\n$72.86M'}
# {'title': '38.\nCrater\n(2023)', 'year': '(2023)', 'certificate': 'PG', 'time': '105 min', 'genre': 'Adventure, Drama, Family', 'rating': '5.0', 'metascore': '65', 'simple_desc': 'After the death of his father, a boy growing up on a lunar mining colony takes a trip to explore a legendary crater, along with his four best friends, prior to permanently leaving the Moon and relocated to another planet.', 'votes': 'Votes:\n1,887'}
# {'title': '40.\nShazam! Fury of the Gods\n(2023)', 'year': '(2023)', 'certificate': 'PG13', 'time': '130 min', 'genre': 'Action, Adventure, Comedy', 'rating': '6.0', 'metascore': '47', 'simple_desc': 'The film continues the story of teenage Billy Batson who, upon reciting the magic word "SHAZAM!" is transformed into his adult Super Hero alter ego, Shazam.', 'votes': 'Votes:\n68,412'}
# {'title': '43.\nThe Suicide Squad\n(2021)', 'year': '(2021)', 'certificate': 'M18', 'time': '132 min', 'genre': 'Action, Adventure, Comedy', 'rating': '7.2', 'metascore': '72', 'simple_desc': 'Supervillains Harley Quinn, Bloodsport, Peacemaker, and a collection of nutty cons at Belle Reve prison join the super-secret, super-shady Task Force X as they are dropped off at the remote, enemy-infused island of Corto Maltese.', 'votes': 'Votes:\n371,263\n| Gross:\n$55.82M'}
# {'title': '49.\nInterstellar\n(2014)', 'year': '(2014)', 'certificate': 'PG13', 'time': '169 min', 'genre': 'Adventure, Drama, Sci-Fi', 'rating': '8.7', 'metascore': '74', 'simple_desc': 'When Earth becomes uninhabitable in the future, a farmer and ex-NASA pilot, Joseph Cooper, is tasked to pilot a spacecraft, along with a team of researchers, to find a new planet for humans.', 'votes': 'Votes:\n1,905,504\n| Gross:\n$188.02M'}
# {'title': '50.\n65\n(2023)', 'year': '(2023)', 'certificate': 'PG13', 'time': '93 min', 'genre': 'Action, Adventure, Drama', 'rating': '5.4', 'metascore': '40', 'simple_desc': "An astronaut crash lands on a mysterious planet only to discover he's not alone.", 'votes': 'Votes:\n42,880'}

# %% [markdown]
# Creating a scraping function
# Now let's create a function that does the same as above but it can be reused several times for different URLs.

# %%
def get_movies(url):
    resp = requests.get(url)
    content = BeautifulSoup(resp.content, 'lxml')

    movie_list = []

    for movie in content.select('.lister-item-content'):

        try:
            data = {
                "title": movie.select('.lister-item-header')[0].get_text().strip(),
                "year": movie.select('.lister-item-year')[0].get_text().strip(),
                "certificate": movie.select('.certificate')[0].get_text().strip(),
                "time": movie.select(".runtime")[0].get_text().strip(),
                "genre": movie.select(".genre")[0].get_text().strip(),
                "rating": movie.select(".ratings-imdb-rating")[0].get_text().strip(),
                "metascore": movie.select(".metascore")[0].get_text().strip(),
                "simple_desc": movie.select(".text-muted")[2].get_text().strip(),
                "votes": movie.select(".sort-num_votes-visible")[0].get_text().strip(),
            }

        except IndexError:
            continue

        movie_list.append(data)

    return pd.DataFrame(movie_list)

# %% [markdown]
# ## Scraping movies of different genres
# The **get_movies()** function we write above can parse details from the IMDB web page of different genre URLs and can save them as a CSV file. So by using this function it is possible to scrape all genres that can be saved as separate CSV files. So let's see how this can be done.

# %%
url = 'https://www.imdb.com/search/title/?genres=adventure'
# Calling the function
get_movies(url)
# Out:
#                                                 title        year certificate  \
# 0          1.\nGuardians of the Galaxy Vol. 3\n(2023)      (2023)        PG13
# 1   2.\nDungeons & Dragons: Honor Among Thieves\n(...      (2023)        PG13
# 2             3.\nThe Super Mario Bros. Movie\n(2023)      (2023)          PG
# 3                10.\nGuardians of the Galaxy\n(2014)      (2014)        PG13
# 4                      11.\nPeter Pan & Wendy\n(2023)      (2023)          PG
# 5                            12.\nGhosted\n(I) (2023)  (I) (2023)        NC16
# 6         14.\nGuardians of the Galaxy Vol. 2\n(2017)      (2017)        PG13
# 7                                 15.\nFast X\n(2023)      (2023)        PG13
# 8      19.\nAnt-Man and the Wasp: Quantumania\n(2023)      (2023)          PG
# 9                         21.\nDune: Part One\n(2021)      (2021)        PG13
# 10              22.\nAvatar: The Way of Water\n(2022)      (2022)        PG13
# 11                 29.\nKnights of the Zodiac\n(2023)      (2023)        PG13
# 12     31.\nEverything Everywhere All at Once\n(2022)      (2022)         M18
# 13                                38.\nCrater\n(2023)      (2023)          PG
# 14              40.\nShazam! Fury of the Gods\n(2023)      (2023)        PG13
# 15                     43.\nThe Suicide Squad\n(2021)      (2021)         M18
# 16                          49.\nInterstellar\n(2014)      (2014)        PG13
# 17                                    50.\n65\n(2023)      (2023)        PG13
#
#        time                         genre rating metascore  \
# 0   150 min     Action, Adventure, Comedy    8.3        64
# 1   134 min     Action, Adventure, Comedy    7.4        72
# 2    92 min  Animation, Adventure, Comedy    7.2        46
# 3   121 min     Action, Adventure, Comedy    8.0        76
# 4   106 min     Action, Adventure, Comedy    4.1        61
# 5   116 min     Action, Adventure, Comedy    5.8        34
# 6   136 min     Action, Adventure, Comedy    7.6        67
# 7   141 min      Action, Adventure, Crime    6.4        55
# 8   124 min     Action, Adventure, Comedy    6.2        48
# 9   155 min      Action, Adventure, Drama    8.0        74
# 10  192 min    Action, Adventure, Fantasy    7.7        67
# 11  112 min      Action, Adventure, Drama    4.6        34
# 12  139 min     Action, Adventure, Comedy    7.8        81
# 13  105 min      Adventure, Drama, Family    5.0        65
# 14  130 min     Action, Adventure, Comedy    6.0        47
# 15  132 min     Action, Adventure, Comedy    7.2        72
# 16  169 min      Adventure, Drama, Sci-Fi    8.7        74
# 17   93 min      Action, Adventure, Drama    5.4        40
#
#                                           simple_desc  \
# 0   Still reeling from the loss of Gamora, Peter Q...
# 1   A charming thief and a band of unlikely advent...
# 2   The story of The Super Mario Bros. on their jo...
# 3   A group of intergalactic criminals must pull t...
# 4   Follow the adventures of Peter Pan, a boy who ...
# 5   Cole falls head over heels for enigmatic Sadie...
# 6   The Guardians struggle to keep together as a t...
# 7   Dom Toretto and his family are targeted by the...
# 8   Scott Lang and Hope Van Dyne are dragged into ...
# 9   A noble family becomes embroiled in a war for ...
# 10  Jake Sully lives with his newfound family form...
# 11  When a goddess of war reincarnates in the body...
# 12  A middle-aged Chinese immigrant is swept up in...
# 13  After the death of his father, a boy growing u...
# 14  The film continues the story of teenage Billy ...
# 15  Supervillains Harley Quinn, Bloodsport, Peacem...
# 16  When Earth becomes uninhabitable in the future...
# 17  An astronaut crash lands on a mysterious plane...
#
#                                     votes
# 0                         Votes:\n123,203
# 1                          Votes:\n99,139
# 2                         Votes:\n111,060
# 3   Votes:\n1,212,863\n| Gross:\n$333.18M
# 4                          Votes:\n20,047
# 5                          Votes:\n37,357
# 6     Votes:\n710,520\n| Gross:\n$389.81M
# 7                          Votes:\n12,746
# 8                         Votes:\n145,150
# 9     Votes:\n674,432\n| Gross:\n$108.33M
# 10    Votes:\n380,345\n| Gross:\n$659.68M
# 11                          Votes:\n2,568
# 12     Votes:\n444,734\n| Gross:\n$72.86M
# 13                          Votes:\n1,887
# 14                         Votes:\n68,412
# 15     Votes:\n371,263\n| Gross:\n$55.82M
# 16  Votes:\n1,905,504\n| Gross:\n$188.02M
# 17                         Votes:\n42,880

# %%
df_data = pd.DataFrame()
for genre, url in url_dict.items():
    df_data = pd.concat([df_data, get_movies(url)])

df_data.to_csv('movies.csv')
df_data.head()
# Out:
#                                                title    year certificate  \
# 0         1.\nGuardians of the Galaxy Vol. 3\n(2023)  (2023)        PG13
# 1  2.\nDungeons & Dragons: Honor Among Thieves\n(...  (2023)        PG13
# 2            3.\nThe Super Mario Bros. Movie\n(2023)  (2023)          PG
# 3               10.\nGuardians of the Galaxy\n(2014)  (2014)        PG13
# 4                     11.\nPeter Pan & Wendy\n(2023)  (2023)          PG
#
#       time                         genre rating metascore  \
# 0  150 min     Action, Adventure, Comedy    8.3        64
# 1  134 min     Action, Adventure, Comedy    7.4        72
# 2   92 min  Animation, Adventure, Comedy    7.2        46
# 3  121 min     Action, Adventure, Comedy    8.0        76
# 4  106 min     Action, Adventure, Comedy    4.1        61
#
#                                          simple_desc  \
# 0  Still reeling from the loss of Gamora, Peter Q...
# 1  A charming thief and a band of unlikely advent...
# 2  The story of The Super Mario Bros. on their jo...
# 3  A group of intergalactic criminals must pull t...
# 4  Follow the adventures of Peter Pan, a boy who ...
#
#                                    votes
# 0                        Votes:\n123,203
# 1                         Votes:\n99,139
# 2                        Votes:\n111,060
# 3  Votes:\n1,212,863\n| Gross:\n$333.18M
# 4                         Votes:\n20,047
